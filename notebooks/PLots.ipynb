# %%
import os
import seaborn as sns
import pandas as pd
from openpyxl import Workbook, load_workbook
import numpy as np
import sympy as sy
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.pyplot import *
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')
from  matplotlib import *
from math import exp, log, sqrt
from scipy import *
# %matplotlib inline

# %%
#    gqL = gqV + gqA
#    gqR = gqV - gqA
gchi, MZp, gqV, gqL, gqR, Me, MMU, MTA, MU, MC, MT, MD, MS, MB, Mchi, Mq, X, gqA, gqV, cw = sy.symbols('gchi MZp gqV gqL gqR ME MMU Mta Mu Mc Mt Md MS Mb Mchi Mq X gqA gqV cw', real=True)
gZp = 1  
gqA = 0.0

def BR_Zp_qq(MZp, gchi, gqA, gqV,Mchi): 
    return (3*gZp**2*MZp**3*(sy.sqrt(-4*MB**2*MZp**2 + MZp**4)*(gqA**2*(-4*MB**2 + MZp**2) + gqV**2*(2*MB**2 + MZp**2))+
                              sy.sqrt(-4*MC**2*MZp**2 + MZp**4)*(gqA**2*(-4*MC**2 + MZp**2) + gqV**2*(2*MC**2 + MZp**2)) +
                              sy.sqrt(-4*MD**2*MZp**2 + MZp**4)*(gqA**2*(-4*MD**2 + MZp**2) + gqV**2*(2*MD**2 + MZp**2)) + 
                              sy.sqrt(-4*MS**2*MZp**2 + MZp**4)*(gqA**2*(-4*MS**2 + MZp**2) + gqV**2*(2*MS**2 + MZp**2)) + 
                              sy.sqrt(-4*MT**2*MZp**2 + MZp**4)*(gqA**2*(-4*MT**2 + MZp**2) + gqV**2*(2*MT**2 + MZp**2)) + 
                              sy.sqrt(-4*MU**2*MZp**2 + MZp**4)*(gqA**2*(-4*MU**2 + MZp**2) + gqV**2*(2*MU**2 + MZp**2))))/(2*gchi**2*sy.sqrt(MZp**2)*(-4*Mchi**2*MZp**2 + MZp**4)**(3/2) +
                              3*gZp**2*MZp**3*sy.sqrt(-4*MB**2*MZp**2 + MZp**4)*(gqA**2*(-4*MB**2 + MZp**2) + gqV**2*(2*MB**2 + MZp**2)) + 
                              3*gZp**2*MZp**3*sy.sqrt(-4*MC**2*MZp**2 + MZp**4)*(gqA**2*(-4*MC**2 + MZp**2) + gqV**2*(2*MC**2 + MZp**2)) + 
                              3*gZp**2*MZp**3*sy.sqrt(-4*MD**2*MZp**2 + MZp**4)*(gqA**2*(-4*MD**2 + MZp**2) + gqV**2*(2*MD**2 + MZp**2)) + 
                              3*gZp**2*MZp**3*sy.sqrt(-4*MS**2*MZp**2 + MZp**4)*(gqA**2*(-4*MS**2 + MZp**2) + gqV**2*(2*MS**2 + MZp**2)) +
                              3*gZp**2*MZp**3*sy.sqrt(-4*MT**2*MZp**2 + MZp**4)*(gqA**2*(-4*MT**2 + MZp**2) + gqV**2*(2*MT**2 + MZp**2)) + 
                              3*gZp**2*MZp**3*sy.sqrt(-4*MU**2*MZp**2 + MZp**4)*(gqA**2*(-4*MU**2 + MZp**2) + gqV**2*(2*MU**2 + MZp**2)))

def BR_Zp_XX(MZp, gchi, gqA, gqV,Mchi):
    return sy.simplify((2*gchi**2*sy.sqrt(MZp**2)*(-4*Mchi**2*MZp**2 + MZp**4)**(3/2))/(2*gchi**2*sy.sqrt(MZp**2)*(-4*Mchi**2*MZp**2 + 
                         MZp**4)**(3/2) + 3*gZp**2*MZp**3*sy.sqrt(-4*MB**2*MZp**2 + MZp**4)*(gqA**2*(-4*MB**2 + MZp**2) + gqV**2*(2*MB**2 + MZp**2)) +
                         3*gZp**2*MZp**3*sy.sqrt(-4*MC**2*MZp**2 + MZp**4)*(gqA**2*(-4*MC**2 + MZp**2) + gqV**2*(2*MC**2 + MZp**2)) +
                         3*gZp**2*MZp**3*sy.sqrt(-4*MD**2*MZp**2 + MZp**4)*(gqA**2*(-4*MD**2 + MZp**2) + gqV**2*(2*MD**2 + MZp**2)) + 
                         3*gZp**2*MZp**3*sy.sqrt(-4*MS**2*MZp**2 + MZp**4)*(gqA**2*(-4*MS**2 + MZp**2) + gqV**2*(2*MS**2 + MZp**2)) + 
                         3*gZp**2*MZp**3*sy.sqrt(-4*MT**2*MZp**2 + MZp**4)*(gqA**2*(-4*MT**2 + MZp**2) + gqV**2*(2*MT**2 + MZp**2)) +
                         3*gZp**2*MZp**3*sy.sqrt(-4*MU**2*MZp**2 + MZp**4)*(gqA**2*(-4*MU**2 + MZp**2) + gqV**2*(2*MU**2 + MZp**2)))
                         )

BR_Zp_XX(MZp, gchi, gqA, gqV,Mchi)#.evalf()
BR_Zp_qq(MZp, gchi, gqA, gqV,Mchi)
# Out:
# 3*MZp**3*(gqV**2*(2*MS**2 + MZp**2)*sqrt(-4*MS**2*MZp**2 + MZp**4) + gqV**2*(MZp**2 + 2*Mb**2)*sqrt(MZp**4 - 4*MZp**2*Mb**2) + gqV**2*(MZp**2 + 2*Mc**2)*sqrt(MZp**4 - 4*MZp**2*Mc**2) + gqV**2*(MZp**2 + 2*Md**2)*sqrt(MZp**4 - 4*MZp**2*Md**2) + gqV**2*(MZp**2 + 2*Mt**2)*sqrt(MZp**4 - 4*MZp**2*Mt**2) + gqV**2*(MZp**2 + 2*Mu**2)*sqrt(MZp**4 - 4*MZp**2*Mu**2))/(3*MZp**3*gqV**2*(2*MS**2 + MZp**2)*sqrt(-4*MS**2*MZp**2 + MZp**4) + 3*MZp**3*gqV**2*(MZp**2 + 2*Mb**2)*sqrt(MZp**4 - 4*MZp**2*Mb**2) + 3*MZp**3*gqV**2*(MZp**2 + 2*Mc**2)*sqrt(MZp**4 - 4*MZp**2*Mc**2) + 3*MZp**3*gqV**2*(MZp**2 + 2*Md**2)*sqrt(MZp**4 - 4*MZp**2*Md**2) + 3*MZp**3*gqV**2*(MZp**2 + 2*Mt**2)*sqrt(MZp**4 - 4*MZp**2*Mt**2) + 3*MZp**3*gqV**2*(MZp**2 + 2*Mu**2)*sqrt(MZp**4 - 4*MZp**2*Mu**2) + 2*gchi**2*(MZp**4 - 4*MZp**2*Mchi**2)**1.5*Abs(MZp))

# %%
MSd, Mh, MZ, cw, MW, alpha, Ca, Sa= sy.symbols('MSd Mh MZ cw MW alpha Ca Sa', real=True)
vev, ytau,yup,ydo, ys = sy.symbols('vev ytau yup ydo ys', real=True)
yb, ye, ym, yc, yt, ee, gsd, gq, ychi, X= sy.symbols('yb ye ym yc yt ee gsd gq ychi X', real=True)
gZp = 1 
gsd = -2*gchi
vev2= sy.symbols('vev2', real=True)
yd1x1, yd2x2, yd3x3, vev2, lam1, lam2, lam3 = sy.symbols('yd1x1 yd2x2 yd3x3 vev2 lam1 lam2 lam3', real=True)
def BR_Sd_qq(MZp, gchi, gqA, gqV,Mchi): 
    return 

def BR_Sd_XX(MZp, gchi, gqA, gqV,Mchi):
    return

# %%
file1 = "/home/yoxara/2MDM/data/sigmaZp.txt"
data = np.genfromtxt(file1, skip_header=1)
xsecZp = data[:, 2].flatten()
file2 = "/home/yoxara/2MDM/data/sigmaZpchichi.txt"
data2 = np.genfromtxt(file2, skip_header=1)
xsecZpXX = data2[:, 2].flatten()
MZp_values = [500, 1000, 1500, 2000, 2500, 3000]

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(MZp_values, xsecZp, color="b", linestyle="-", label= r"$\sigma(p p \to Z^{\prime})$")#marker="o"
plt.plot(MZp_values, xsecZpXX, color="r", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \chi \chi)$")#marker="o"
ax.set_xlabel(r'$M_{Z^\prime}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 0.5$",
                  r"$g_q^A = 0.0$, $g_q^V = 0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.7,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()

# %%
X = sy.symbols('X', real=True)
MU = 0.00255
MC = 1.27
MT = 172
MD = 0.00504
MS = 0.101
MB = 4.7
Mchi= 65
gchi = 0.1
gqV= 0.5 
gZp = 1 
MZp = MZp_values

# %%
BR_Zp_qq_list = []
BR_Zp_XX_list = []
xsecXBR_Zpqq_list = []
xsecXBR_ZpXX_list = []

for MZp, xs in zip(MZp_values, xsecZp):
    BR_Zp_qq_val = BR_Zp_qq(MZp, gchi, gqA, gqV, Mchi)
    BR_Zp_XX_val = BR_Zp_XX(MZp, gchi, gqA, gqV, Mchi)
    BR_Zp_qq_list.append(BR_Zp_qq_val)
    BR_Zp_XX_list.append(BR_Zp_XX_val)
    xsecXBR_Zpqq_list.append(xs * BR_Zp_qq_val)
    xsecXBR_ZpXX_list.append(xs * BR_Zp_XX_val)

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(10, 7))
plt.plot(MZp_values, xsecXBR_ZpXX_list, color='blue', label=r"'$\sigma \times BR(Z^\prime \to \chi \chi)$")
plt.xlabel(r'$M_{Z^\prime}$ (GeV)')
plt.ylabel(r'$\sigma \times BR(Z^\prime \to \chi \chi)$ (pb)')
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#legend.get_frame().set_edgecolor('none')
#legend.get_frame().set_facecolor('none')
plt.show()

# %%
file3 = "/home/yoxara/2MDM/data/sigmaSdnloXX.txt"
data3 = np.genfromtxt(file3, skip_header=1)
xsecSd = data3[:, 2].flatten()
file4 = "/home/yoxara/2MDM/data/sigmaSdnlochichi.txt"
data4 = np.genfromtxt(file4, skip_header=1)
xsecSdXX = data4[:, 2].flatten()
MZp_values = [140,300,500, 1000, 1500, 2000, 2500]
xsecSd
# Out:
# array([9.08948700e-02, 3.36148840e-02, 1.77817149e-02, 6.18290645e-04,
#        4.84971954e-05, 6.01627752e-06, 9.76337893e-07])

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(MZp_values, xsecSd, color="b", linestyle="-", label= r"$\sigma(p p \to S)$")#marker="o"
plt.plot(MZp_values, xsecSdXX, color="r", linestyle=":", label= r"$\sigma(p p \to S \to \chi \chi)$")#marker="o"
ax.set_xlabel(r'$M_{S}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 0.5$",
                  r"$y_{\chi} = 1.0$, $M_{Z^{\prime}} = 1000$",
                  r"$\sin(\alpha)=0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.7,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()
