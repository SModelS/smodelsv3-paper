# %%
import os
import seaborn as sns
import pandas as pd
from openpyxl import Workbook, load_workbook
import numpy as np
import sympy as sy
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.pyplot import *
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')
from  matplotlib import *
from math import exp, log, sqrt
from scipy import *
# %matplotlib inline

# %%
#    gqL = gqV + gqA
#    gqR = gqV - gqA
gchi, MZp, gqV, gqL, gqR, Me, MMU, MTA, MU, MC, MT, MD, MS, MB, Mchi, Mq, X, gqA, gqV, cw = sy.symbols('gchi MZp gqV gqL gqR ME MMU Mta Mu Mc Mt Md MS Mb Mchi Mq X gqA gqV cw', real=True)
gZp = 1  
gqA = 0.0

# %% [raw]
# MSd, Mh, MZ, cw, MW, alpha, Ca, Sa= sy.symbols('MSd Mh MZ cw MW alpha Ca Sa', real=True)
# vev, ytau,yup,ydo, ys = sy.symbols('vev ytau yup ydo ys', real=True)
# yb, ye, ym, yc, yt, ee, gsd, gq, ychi, X= sy.symbols('yb ye ym yc yt ee gsd gq ychi X', real=True)
# gZp = 1
# gsd = -2*gchi
# vev2= sy.symbols('vev2', real=True)
# yd1x1, yd2x2, yd3x3, vev2, lam1, lam2, lam3 = sy.symbols('yd1x1 yd2x2 yd3x3 vev2 lam1 lam2 lam3', real=True)
# def BR_Sd_qq(MZp, gchi, gqA, gqV,Mchi):
#     return
#
# def BR_Sd_XX(MZp, gchi, gqA, gqV,Mchi):
#     return

# %%
file1 = "/home/yoxara/2MDM/data/sigmaZpjNew.txt"# gqV =0.1"/home/yoxara/2MDM/data/sigmaZp.txt"
data = np.genfromtxt(file1, skip_header=1,max_rows=13)
data1 = np.genfromtxt(file1, skip_header=1)
xsecZp = data[:, 2].flatten() #gqV =0.1
xsecZp2 = data1[13:, 2].flatten() #gqV =0.25
file2 = "/home/yoxara/2MDM/data/sigmaZpXdXdjNew.txt"#"/home/yoxara/2MDM/data/sigmaZpXdXdj.txt"
data2 = np.genfromtxt(file2, skip_header=1,max_rows=13)
xsecZpXX = data2[:, 2].flatten()
data2Zp = np.genfromtxt(file2, skip_header=1)
xsecZpXX2 = data2Zp[13:, 2].flatten()
MZp_values = list(range(250, 3500, 250))#[500, 1000, 1500, 2000, 2500, 3000]
xsecZpXX2
#xsecZp2
# Out:
# array([3.04774300e+02, 4.25079060e+01, 1.08883510e+01, 3.73691120e+00,
#        1.51448164e+00, 6.77699160e-01, 3.24266155e-01, 1.64150892e-01,
#        8.54080380e-02, 4.61829209e-02, 2.56816712e-02, 1.44379193e-02,
#        8.31296750e-03])

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(MZp_values, xsecZp, color="b", linestyle="-", label= r"$\sigma(p p \to Z^{\prime})$")#marker="o"
plt.plot(MZp_values, xsecZpXX, color="r", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \chi \chi j)$")#marker="o"
plt.plot(MZp_values, xsecZp2, color="brown", linestyle="-", label= r"$\sigma(p p \to Z^{\prime})$")#marker="o"
plt.plot(MZp_values, xsecZpXX2, color="yellow", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \chi \chi j)$")#marker="o"
ax.set_xlabel(r'$M_{Z^\prime}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 0.5$",
                  r"$g_q^A = 0.0$, $g_q^V = 0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.7,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)
#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()

# %%
X = sy.symbols('X', real=True)
MU = 0.00255
MC = 1.27
MT = 172
MD = 0.00504
MS = 0.101
MB = 4.7
Mchi= 65
gchi = 0.1
gqV= 0.5 
gZp = 1 
MZp = MZp_values

# %%
file3 = "/home/yoxara/2MDM/data/sigmaSd.txt"
data3 = np.genfromtxt(file3, skip_header=1)
xsecSd = data3[:, 2].flatten()
file5 = "/home/yoxara/2MDM/data/sigmah2.txt"
data5 = np.genfromtxt(file5, skip_header=1)
xsech = data5[:, 2].flatten()
file6 = "/home/yoxara/2MDM/data/sigmah.txt"
data6 = np.genfromtxt(file6, skip_header=1)
xsech1 = data6[:, 2].flatten()
file4 = "/home/yoxara/2MDM/data/sigmaSdXdXdjnlo.txt" #"/home/yoxara/2MDM/data/sigmaSdnlochichi.txt"
data4 = np.genfromtxt(file4, skip_header=1)
xsecSdXX = data4[:, 2].flatten()
MSd_values = [140, 300, 500, 700, 900, 1100, 1300, 1500, 1700, 1900, 2100, 2400]
Mh_values = [140, 300, 500, 700, 900, 1100, 1300, 1500, 1700, 1900, 2100, 2400]
MSd_values1 = [140,300,500, 1000, 1500, 2000, 2500]
xsecSd
# Out:
# array([4.5886e-01, 1.3464e-01, 6.3689e-02, 1.3068e-02, 3.2409e-03,
#        9.5423e-04, 3.2196e-04, 1.2003e-04, 4.8414e-05, 2.0751e-05,
#        9.3572e-06, 3.0525e-06])

# %%
plt.plot(MSd_values, xsech1, color="g", linestyle="-", label= r"$\sigma(p p \to h)$")#marker="o"
plt.plot(MSd_values, xsech, color="g", linestyle="-", label= r"$\sigma(p p \to h)$")#marker="o"

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
#plt.plot(Mh_values, xsech, color="g", linestyle="-", label= r"$\sigma(p p \to h)$")#marker="o"
plt.plot(MSd_values, xsecSd, color="b", linestyle="-", label= r"$\sigma(p p \to S)$")#marker="o"
plt.plot(MSd_values, xsecSdXX, color="r", linestyle=":", label= r"$\sigma(p p \to S \to \chi \chi j)$")#marker="o"
ax.set_xlabel(r'$M_{S}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 0.5$",
                  r"$y_{\chi} = 1.0$, $M_{Z^{\prime}} = 1000$",
                  r"$\sin(\alpha)=0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.5,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)

#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
#plt.plot(Mh_values, xsech, color="g", linestyle="-", label= r"$\sigma(p p \to h)$")#marker="o"
plt.plot(MZp_values, xsecZp, color="magenta", linestyle="-", label= r"$\sigma(p p \to Z^{\prime})$")#marker="o"
plt.plot(MZp_values, xsecZpXX, color="magenta", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \to \chi \chi j)$")#marker="o"
plt.plot(MSd_values, xsecSdXX, color="b", linestyle=":", label= r"$\sigma(p p \to S \to \chi \chi j)$")#marker="o"
plt.plot(MSd_values, xsecSd, color="b", linestyle="-", label= r"$\sigma(p p \to S)$")#marker="o"

ax.set_xlabel(r'$m_{M}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$ [pb]', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
if not os.path.exists('plots/xsec'):
    os.makedirs('plots/xsec')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 1$, $g_q^A = 0.0$",
                   r" $g_q^V = 0.1$, $y_{\chi} = 1.0$,  $\sin(\alpha)=0.2$",
                  r"$m_{Z^{\prime}} = 2 TeV$, $m_{S} = 140 GeV$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.1, 0.1,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.2,
            edgecolor='white',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)
legend.get_frame().set_alpha(0.1)
plt.savefig('plots/xsec/xsecBR.pdf', bbox_inches='tight')
plt.show()

# %%
\SliDT{Production and Event Simulation}{ 
\begin{itemize}
	\IteOne{\href{https://link.springer.com/content/pdf/10.1007/JHEP12(2019)059.pdf}{Measurement of the differential Drell-Yan cross section in p-p collisions at $\sqrt{s} = 13$ TeV}}
	\IteOne{\href{https://feynrules.irmp.ucl.ac.be}{FeynRules}}
	\IteOne{Production and Event Simulation}
	\begin{itemize}
		\IteTwo {Modified \href{https://launchpad.net/mg5amcnlo}{MadGraph5} (\href{https://docplayer.net/64847013-Looping-up-to-be-mad-olivier-mattelaer-ippp-durham-based-on-and-work-in-progress-with-v.html}{New Function: 	\lstinline[]{NP^2>0}}) }
		\begin{itemize}
			\IteThr{Pythia8}
			\IteThr{Delphes}
		\end{itemize}
	\end{itemize}
	\IteOne{Analysis software}
	\begin{itemize}
		\IteTwo {\href{https://launchpad.net/madanalysis5}{MadAnalysis5}}
		\IteTwo {Python}
		numpy, matplotlib, scipy, pandas \href{https://arxiv.org/pdf/1510.07319.pdf}{LHCO\_reader}
	\end{itemize}
\end{itemize}
\refbotS{ \tiny{\href{https://link.springer.com/content/pdf/10.1007/JHEP12(2019)059.pdf}{10.1007/JHEP12(2019)059}, \href{https://link.springer.com/content/pdf/10.1007/JHEP08(2020)019.pdf}{10.1007/JHEP08(2020)019}}} 
}{
The mass of the leptophilic vector boson $m_{\zp}$ and $g_{\ell}$ are the free parameters to be constrained along this work in collider phenomenology. 

\vspace*{1 cm}

In specific terms, I will analyze the following process: $ p p (\overline{\ell} \ell) \to  \overline{\ell} \ell$, where I consider that the charged leptons appear as constituents in hadron beams. 
}




\begin{itemize}
	\IteOne  Implement the models through computational tools to later simulate the interactions of interest. 
	\IteOne Simulate the processes in a Monte Carlo event generator and include the kinematic cuts used by the experimental collaborations. 
	\IteOne Calculate the cross-section of the processes produced at current and future colliders to search for dark matter and new gauge bosons in the standard model extensions proposed in this project: with symmetry group $U(1)_X$%, and 3-3-1 models.
	\IteOne Obtain expected excluded regions from the parameter space of the $Z^{\prime}$ and DM mass-coupling plane for $ p(e)p(e) $ and $p e$ collisions, considering the current and future accessible regions at the LHC, LHeC, and FCCs.
	\IteOne Search for Dark Matter in Colliders
	%\IteOne Find new gauge bosons in colliders by extending the SM with symmetry group $\textbf{U(1)}_\textbf{X}$.
	% \IteOne Analyze Flavor-Changing Neutral Current processes (FCNC) in the 3-3-1 models
\end{itemize}

}
