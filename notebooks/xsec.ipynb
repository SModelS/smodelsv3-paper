# %%
import os
import seaborn as sns
import pandas as pd
from openpyxl import Workbook, load_workbook
import numpy as np
import sympy as sy
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib.pyplot import *
plt.rc('text', usetex=True)
plt.rc('font', family='Times New Roman')
from  matplotlib import *
from math import exp, log, sqrt
from scipy import *
# %matplotlib inline

# %%
gZp = 1  
gqA = 0.0

# %%
#/home/yoxara/2MDM/scripts/sigmaZpjNew.txt
#/home/yoxara/2MDM/scripts/sigmaZpjNew.py
#/home/yoxara/2MDM/scripts/sigmaZpChiChijNew.txt
#/home/yoxara/2MDM/scripts/sigmaZpjChiChiNew.py
Zpj = np.genfromtxt("/home/yoxara/2MDM/data/sigmaZpjNew.txt", skip_header=1)
xsecZp = Zpj[:, 2].flatten()
ZpjChiChi = np.genfromtxt("/home/yoxara/2MDM/data/sigmaZpChiChijNew.txt", skip_header=1)
xsecZpXX = ZpjChiChi[:, 2].flatten()
MZp_values = list(range(200, 3600, 200))
xsecZpXX
xsecZp
# Out:
# array([3.75987000e+02, 4.91582500e+01, 1.29278480e+01, 4.62808540e+00,
#        1.97888320e+00, 9.34589090e-01, 4.75242340e-01, 2.53539447e-01,
#        1.40678526e-01, 8.03849360e-02, 4.67974629e-02, 2.76493475e-02,
#        1.64957885e-02, 9.92396098e-03, 5.94093783e-03, 3.58872110e-03,
#        2.14825418e-03])

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
plt.plot(MZp_values, xsecZp, color="b", linestyle="-", label= r"$\sigma(p p \to Z^{\prime} j ) $")#marker="o"
plt.plot(MZp_values, xsecZpXX, color="r", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \chi \chi j)$")#marker="o"
ax.set_xlabel(r'$M_{Z^\prime}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 1$",
                  r"$g_q^A = 0.0$, $g_q^V = 0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.7,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)
#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()

# %% [raw]
# X = sy.symbols('X', real=True)
# MU = 0.00255
# MC = 1.27
# MT = 172
# MD = 0.00504
# MS = 0.101
# MB = 4.7
# Mchi= 65
# gchi = 1
# gqV= 0.1
# gZp = 1
# ychi = 1.5
# Sa =0.2

# %%
#/home/yoxara/2MDM/scripts/sigmaSdjnew.py
#/home/yoxara/2MDM/scripts/sigmaSdjNewnlo.txt
#/home/yoxara/2MDM/scripts/sigmahxxjnew.py
#/home/yoxara/2MDM/scripts/sigmahNewnlo.txt
#/home/yoxara/2MDM/scripts/sigmaSdxxjnew.py
#/home/yoxara/2MDM/scripts/sigmaSdNewnlo.txt
#file:///home/yoxara/2MDM/2mdm_sigmaSdNewnlo/crossx.html
Sdj = np.genfromtxt("/home/yoxara/2MDM/data/sigmaSdjNewnlo.txt", skip_header=1,max_rows=12)
xsecSdj = Sdj[:, 2].flatten()
#hj = np.genfromtxt("/home/yoxara/2MDM/data/sigmahNewnlo.txt", skip_header=1,max_rows=12)
#xsechjChiChi = hj[:, 2].flatten()
SdjChiChi = np.genfromtxt("/home/yoxara/2MDM/data/sigmaSdNewnlo.txt", skip_header=1,max_rows=12)
xsecSdXX = SdjChiChi[:, 2].flatten()
MSd_values = [140, 300, 500, 700, 900, 1100, 1300, 1500, 1700, 1900, 2100, 2400]

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
#plt.plot(MSd_values, xsech, color="g", linestyle="-", label= r"$\sigma(p p \to h to \chi \chi)$")#marker="o"
plt.plot(MSd_values, xsecSdj, color="b", linestyle="-", label= r"$\sigma(p p \to S)$")#marker="o"
plt.plot(MSd_values, xsecSdXX, color="r", linestyle=":", label= r"$\sigma(p p \to S \to \chi \chi j)$")#marker="o"
ax.set_xlabel(r'$M_{S}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
#if not os.path.exists('plots/xsecZp'):
#    os.makedirs('plots/xsecZp')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 0.5$",
                  r"$y_{\chi} = 1.0$, $M_{Z^{\prime}} = 1000$",
                  r"$\sin(\alpha)=0.1$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.7, 0.5,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.5,
            edgecolor='silver',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)

#plt.savefig('plots/xsecZp/xsecZp.pdf', bbox_inches='tight')
plt.show()

# %%
sns.set_style("white")
fig, ax = plt.subplots(figsize=(8, 6))
#plt.plot(MSd_values, xsech, color="g", linestyle="-", label= r"$\sigma(p p \to h)$")#marker="o"
plt.plot(MZp_values, xsecZp, color="magenta", linestyle="-", label= r"$\sigma(p p \to Z^{\prime} j )$")#marker="o"
plt.plot(MZp_values, xsecZpXX, color="magenta", linestyle=":", label= r"$\sigma(p p \to Z^{\prime} \to \chi \chi j)$")#marker="o"
plt.plot(MSd_values, xsecSdXX, color="b", linestyle=":", label= r"$\sigma(p p \to S \to \chi \chi j)$")#marker="o"
plt.plot(MSd_values, xsecSdj, color="b", linestyle="-", label= r"$\sigma(p p \to S j )$")#marker="o"

ax.set_xlabel(r'$m_{M}$ [GeV]', size=18, color='black', labelpad=5, loc="right")
ax.set_ylabel(r'$\sigma$ [pb]', size=18, color='black',labelpad=5, loc="top")
ax.tick_params(axis='x', labelcolor='black', labelsize=14)
ax.tick_params(axis='y', labelcolor='black', labelsize=14)
plt.xticks(fontsize=16)
plt.yticks(fontsize=16)
plt.yscale('log')
ax.tick_params(direction='in', length=10, width=1.1, colors='black', which='major', top=True, right=True)
ax.tick_params(direction='in', length=5, width=0.6, colors='black', which='minor', top=True, right=True)
ax.xaxis.set_ticks_position('both')
ax.yaxis.set_ticks_position('both')
for spine in ['left', 'right', 'top', 'bottom']:
    ax.spines[spine].set_linewidth(1.2)
sns.despine(left=False, bottom=False, right=False, top=False, offset=None, trim=False)
if not os.path.exists('plots/xsec'):
    os.makedirs('plots/xsec')
important_info = (r"$M_{\chi} = 65$ [GeV], $g_{\chi} = 1$, $g_q^A = 0.0$",
                   r" $g_q^V = 0.1$, $y_{\chi} = 1.0$,  $\sin(\alpha)=0.2$")
#                  r"$S_a = 0.01$")
multiline_info = "\n".join(important_info)   
plt.tight_layout()
ax.text(0.1, 0.1,  
        multiline_info,
        transform=ax.transAxes,
        fontsize=12,  
        color='black',
        #fontweight='bold',
        bbox=dict(
            facecolor='silver',
            alpha=0.2,
            edgecolor='white',
            boxstyle='round,pad=0.8',
            linewidth=0.2
        ))
plt.grid(True, which='both', linestyle='--', linewidth=0.5)
legend = plt.legend(loc='upper right', fontsize=14)
legend.get_frame().set_alpha(0.1)
plt.savefig('plots/xsec/xsecBR.pdf', bbox_inches='tight')
plt.show()
